# %% [markdown]
# SQL
# ---
#
# Let's drop everything into a table, and from there we can pick out the unique station identifiers (unit), produce the difference columns, do our cleaning, and create a new table (in a separate database) that has our cleaned data. Yes, this should have been done from the get-go, but better late than never...

# %%
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2

database = 'raw_stations'
user = 'mikemoran'

# %%
engine = create_engine(f'postgres://{user}@localhost/{database}')
if not database_exists(engine.url):
    create_database(engine.url)

# %%
import os

files = [f'raw_data/{f}' for f in sorted(os.listdir('raw_data/'))]
split = 'raw_data/turnstile_141018.txt'
modern_files = files[files.index(split):]
modern_files[:5]
# Out:
# ['raw_data/turnstile_141018.txt',
#  'raw_data/turnstile_141025.txt',
#  'raw_data/turnstile_141101.txt',
#  'raw_data/turnstile_141108.txt',
#  'raw_data/turnstile_141115.txt']

# %% [markdown]
# Modern Style
# --------------

# %%
def load_turnstile(filename):
    df = pd.read_csv(filename, header=0,
                     parse_dates=[['DATE', 'TIME']], infer_datetime_format=True,)
    df.columns = df.columns.str.strip().str.lower().str.replace('/', '_')
    return df

# %%
for filename in modern_files:
    df = load_turnstile(filename)
    df.to_sql('raw', engine, if_exists='append')

# %%
conn = None
conn = psycopg2.connect(database=database, user=user)

query = '''
    select * from raw
    where unit = 'R072';'''
r072 = pd.read_sql(query, conn)
r072.head()
# Out:
#     index           date_time   c_a  unit       scp          station linename  \
# 0  182004 2016-05-07 00:00:00  R550  R072  00-00-00  34 ST-HUDSON YD        7
# 1  182005 2016-05-07 04:00:00  R550  R072  00-00-00  34 ST-HUDSON YD        7
# 2  182006 2016-05-07 08:00:00  R550  R072  00-00-00  34 ST-HUDSON YD        7
# 3  182007 2016-05-07 12:00:00  R550  R072  00-00-00  34 ST-HUDSON YD        7
# 4  182008 2016-05-07 16:00:00  R550  R072  00-00-00  34 ST-HUDSON YD        7
#
#   division     desc  entries  exits
# 0      IRT  REGULAR     8267  35122
# 1      IRT  REGULAR     8267  35136
# 2      IRT  REGULAR     8267  35140
# 3      IRT  REGULAR     8270  35161
# 4      IRT  REGULAR     8274  35186

# %% [markdown]
# Old Style
# -----------

# %%
old_files = files[:files.index(split)]
old_files = list(filter(lambda x: 'turnstile' in x, old_files))
old_files[:5]
# Out:
# ['raw_data/turnstile_100505.txt',
#  'raw_data/turnstile_100508.txt',
#  'raw_data/turnstile_100515.txt',
#  'raw_data/turnstile_100522.txt',
#  'raw_data/turnstile_100605.txt']

# %%
test = pd.read_csv(old_files[0], header=None)
test.head()
# Out:
#      0     1         2         3         4        5        6       7   \
# 0  A002  R051  02-00-00  04-17-10  00:00:00  REGULAR  2704717  928793
# 1  A002  R051  02-00-00  04-18-10  08:00:00  REGULAR  2705436  929002
# 2  A002  R051  02-00-00  04-19-10  16:00:00  REGULAR  2706335  929588
# 3  A002  R051  02-00-00  04-20-10  16:00:00  REGULAR  2707710  930067
# 4  A002  R051  02-00-00  04-21-10  20:00:00  REGULAR  2710045  930698
#
#          8         9     ...           33        34       35         36  \
# 0  04-17-10  04:00:00    ...     04-18-10  00:00:00  REGULAR  2705426.0
# 1  04-18-10  12:00:00    ...     04-19-10  08:00:00  REGULAR  2705937.0
# 2  04-19-10  20:00:00    ...     04-20-10  08:00:00     DOOR  2707246.0
# 3  04-20-10  20:00:00    ...     04-21-10  16:00:00  REGULAR  2709171.0
# 4  04-22-10  00:00:00    ...     04-22-10  20:00:00  REGULAR  2711562.0
#
#          37        38        39       40         41        42
# 0  928987.0  04-18-10  04:00:00  REGULAR  2705426.0  928987.0
# 1  929229.0  04-19-10  12:00:00  REGULAR  2706063.0  929533.0
# 2  929705.0  04-20-10  12:00:00     OPEN  2707385.0  930006.0
# 3  930618.0  04-21-10  18:40:52     DOOR  2709868.0  930669.0
# 4  931222.0  04-23-10  00:00:00  REGULAR  2711702.0  931240.0
#
# [5 rows x 43 columns]

# %%
# pd.read_csv(old_files[0], header=None, usecols=[0, 1, 2, 3, 4, 5, 6, 7])
# pd.read_csv(old_files[0], header=None, usecols=[0, 1, 2, 8, 9, 10, 11, 12])
# pd.read_csv(old_files[0], header=None, usecols=[0, 1, 2, 13, 14, 15, 16, 17])

# %%
import itertools

start = [0, 1, 2]
iterable = range(3, 43)
n = 5
fillvalue = 0
remainders = list(itertools.zip_longest(*[iter(iterable)]*n, fillvalue=fillvalue))
column_vals = [[*start, *row] for row in remainders]
list(column_vals)
# Out:
# [[0, 1, 2, 3, 4, 5, 6, 7],
#  [0, 1, 2, 8, 9, 10, 11, 12],
#  [0, 1, 2, 13, 14, 15, 16, 17],
#  [0, 1, 2, 18, 19, 20, 21, 22],
#  [0, 1, 2, 23, 24, 25, 26, 27],
#  [0, 1, 2, 28, 29, 30, 31, 32],
#  [0, 1, 2, 33, 34, 35, 36, 37],
#  [0, 1, 2, 38, 39, 40, 41, 42]]

# %%
# for a single file, need eight calls to pd.read_csv
column_names = ['c_a', 'unit', 'scp', 'date', 'time', 'desc', 'entries', 'exits']
frames = [pd.read_csv(old_files[0], header=None, usecols=usecols, names=column_names)
          for usecols in column_vals]
full_frame = pd.concat(frames, axis=0)
full_frame['date_time'] = pd.to_datetime(
    (full_frame.date + full_frame.time).str.strip(),
    format='%m-%d-%y%H:%M:%S')
full_frame.dropna(inplace=True)
full_frame.reset_index(drop=True, inplace=True)
full_frame.drop(['date', 'time'], inplace=True, axis=1)
full_frame.tail()
# Out:
#          c_a  unit       scp     desc  entries  exits           date_time
# 237010  S102  R165  00-05-01  REGULAR     75.0    0.0 2010-04-18 02:00:00
# 237011  S102  R165  00-05-01  REGULAR     76.0    0.0 2010-04-19 10:00:00
# 237012  S102  R165  00-05-01  REGULAR     76.0    0.0 2010-04-20 18:00:00
# 237013  S102  R165  00-05-01  REGULAR     76.0    0.0 2010-04-22 02:00:00
# 237014  S102  R165  00-05-01  REGULAR     76.0    0.0 2010-04-23 07:07:53

# %%
def load_turnstile_old(filename, **kwargs):
    frames = [pd.read_csv(filename, header=None, usecols=usecols,
                          names=column_names, **kwargs)
              for usecols in column_vals]
    full_frame = pd.concat(frames, axis=0)
    full_frame.dropna(inplace=True)
    full_frame['date_time'] = pd.to_datetime(
        full_frame.date + full_frame.time,
        format='%m-%d-%y%H:%M:%S')
    full_frame.drop(['date', 'time'], axis=1, inplace=True)
    full_frame.reset_index(drop=True, inplace=True)
    return full_frame

# %%
for filename in old_files:
    print(filename)
    df = load_turnstile_old(filename)
    df.to_sql('raw', engine, if_exists='append')
# Out:
# raw_data/turnstile_100505.txt
# raw_data/turnstile_100508.txt
# raw_data/turnstile_100515.txt
# raw_data/turnstile_100522.txt
# raw_data/turnstile_100605.txt
# raw_data/turnstile_100612.txt
# raw_data/turnstile_100619.txt
# raw_data/turnstile_100626.txt
# raw_data/turnstile_100703.txt
# raw_data/turnstile_100710.txt
# raw_data/turnstile_100717.txt
# raw_data/turnstile_100724.txt
# raw_data/turnstile_100731.txt
# raw_data/turnstile_100807.txt
# raw_data/turnstile_100814.txt
# raw_data/turnstile_100821.txt
# raw_data/turnstile_100828.txt
# raw_data/turnstile_100904.txt
# raw_data/turnstile_100911.txt
# raw_data/turnstile_100918.txt
# raw_data/turnstile_100925.txt
# raw_data/turnstile_101002.txt
# raw_data/turnstile_101009.txt
# raw_data/turnstile_101016.txt
# raw_data/turnstile_101023.txt
# raw_data/turnstile_101030.txt
# raw_data/turnstile_101106.txt
# raw_data/turnstile_101113.txt
# raw_data/turnstile_101120.txt
# raw_data/turnstile_101127.txt
# raw_data/turnstile_101204.txt
# raw_data/turnstile_101211.txt
# raw_data/turnstile_101218.txt
# raw_data/turnstile_101225.txt
# raw_data/turnstile_110101.txt
# raw_data/turnstile_110108.txt
# raw_data/turnstile_110115.txt
# raw_data/turnstile_110122.txt
# raw_data/turnstile_110129.txt
# raw_data/turnstile_110205.txt
# raw_data/turnstile_110212.txt
# raw_data/turnstile_110219.txt
# raw_data/turnstile_110226.txt
# raw_data/turnstile_110305.txt
# raw_data/turnstile_110312.txt
# raw_data/turnstile_110319.txt
# raw_data/turnstile_110326.txt
# raw_data/turnstile_110402.txt
# raw_data/turnstile_110409.txt
# raw_data/turnstile_110416.txt
# raw_data/turnstile_110423.txt
# raw_data/turnstile_110430.txt
# raw_data/turnstile_110507.txt
# raw_data/turnstile_110514.txt
# raw_data/turnstile_110521.txt
# raw_data/turnstile_110528.txt
# raw_data/turnstile_110604.txt
# raw_data/turnstile_110611.txt
# raw_data/turnstile_110618.txt
# raw_data/turnstile_110625.txt
# raw_data/turnstile_110702.txt
# raw_data/turnstile_110709.txt
# raw_data/turnstile_110716.txt
# raw_data/turnstile_110723.txt
# raw_data/turnstile_110730.txt
# raw_data/turnstile_110806.txt
# raw_data/turnstile_110813.txt
# raw_data/turnstile_110820.txt
# raw_data/turnstile_110827.txt
# raw_data/turnstile_110903.txt
# raw_data/turnstile_110910.txt
# raw_data/turnstile_110917.txt
# raw_data/turnstile_110924.txt
# raw_data/turnstile_111001.txt
# raw_data/turnstile_111008.txt
# raw_data/turnstile_111015.txt
# raw_data/turnstile_111022.txt
# raw_data/turnstile_111029.txt
# raw_data/turnstile_111105.txt
# raw_data/turnstile_111112.txt
# raw_data/turnstile_111119.txt
# raw_data/turnstile_111126.txt
# raw_data/turnstile_111203.txt
# raw_data/turnstile_111210.txt
# raw_data/turnstile_111219.txt
# raw_data/turnstile_111224.txt
# raw_data/turnstile_111231.txt
# raw_data/turnstile_120107.txt
# raw_data/turnstile_120114.txt
# raw_data/turnstile_120121.txt
# raw_data/turnstile_120128.txt
# raw_data/turnstile_120204.txt
# raw_data/turnstile_120211.txt
# raw_data/turnstile_120218.txt
# raw_data/turnstile_120225.txt
# raw_data/turnstile_120303.txt
# raw_data/turnstile_120310.txt
# raw_data/turnstile_120317.txt
# raw_data/turnstile_120324.txt
# raw_data/turnstile_120331.txt
# raw_data/turnstile_120407.txt
# raw_data/turnstile_120414.txt
# raw_data/turnstile_120421.txt
# raw_data/turnstile_120428.txt
# raw_data/turnstile_120505.txt
# /opt/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2847: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# /opt/miniconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1158                         parameters,
# -> 1159                         context)
#    1160             elif not parameters and context.no_parameters:
#
# /opt/miniconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     466     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 467         cursor.executemany(statement, parameters)
#     468
#
# DataError: invalid input syntax for integer: "-"
# LINE 1: ...601', 'R319', '00-03-00', 'DOOR OPEN', 2814000.0, '-', '2012...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# <ipython-input-69-4d0ba15ec19d> in <module>()
#       2     print(filename)
#       3     df = load_turnstile_old(filename)
# ----> 4     df.to_sql('raw', engine, if_exists='append')
#
# /opt/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#    1343         sql.to_sql(self, name, con, flavor=flavor, schema=schema,
#    1344                    if_exists=if_exists, index=index, index_label=index_label,
# -> 1345                    chunksize=chunksize, dtype=dtype)
#    1346
#    1347     def to_pickle(self, path, compression='infer'):
#
# /opt/miniconda3/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#     469     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     470                       index_label=index_label, schema=schema,
# --> 471                       chunksize=chunksize, dtype=dtype)
#     472
#     473
#
# /opt/miniconda3/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1149                          schema=schema, dtype=dtype)
#    1150         table.create()
# -> 1151         table.insert(chunksize)
#    1152         if (not name.isdigit() and not name.islower()):
#    1153             # check for potentially case sensitivity issues (GH7815)
#
# /opt/miniconda3/lib/python3.6/site-packages/pandas/io/sql.py in insert(self, chunksize)
#     664
#     665                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 666                 self._execute_insert(conn, keys, chunk_iter)
#     667
#     668     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# /opt/miniconda3/lib/python3.6/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     639     def _execute_insert(self, conn, keys, data_iter):
#     640         data = [dict((k, v) for k, v in zip(keys, row)) for row in data_iter]
# --> 641         conn.execute(self.insert_statement(), data)
#     642
#     643     def insert(self, chunksize=None):
#
# /opt/miniconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     943             raise exc.ObjectNotExecutableError(object)
#     944         else:
# --> 945             return meth(self, multiparams, params)
#     946
#     947     def _execute_function(self, func, multiparams, params):
#
# /opt/miniconda3/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     261     def _execute_on_connection(self, connection, multiparams, params):
#     262         if self.supports_execution:
# --> 263             return connection._execute_clauseelement(self, multiparams, params)
#     264         else:
#     265             raise exc.ObjectNotExecutableError(self)
#
# /opt/miniconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1051             compiled_sql,
#    1052             distilled_params,
# -> 1053             compiled_sql, distilled_params
#    1054         )
#    1055         if self._has_events or self.engine._has_events:
#
# /opt/miniconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1187                 parameters,
#    1188                 cursor,
# -> 1189                 context)
#    1190
#    1191         if self._has_events or self.engine._has_events:
#
# /opt/miniconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1400                 util.raise_from_cause(
#    1401                     sqlalchemy_exception,
# -> 1402                     exc_info
#    1403                 )
#    1404             else:
#
# /opt/miniconda3/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# /opt/miniconda3/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# /opt/miniconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1157                         statement,
#    1158                         parameters,
# -> 1159                         context)
#    1160             elif not parameters and context.no_parameters:
#    1161                 if self.dialect._has_events:
#
# /opt/miniconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     465
#     466     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 467         cursor.executemany(statement, parameters)
#     468
#     469     def do_execute(self, cursor, statement, parameters, context=None):
#
# DataError: (psycopg2.DataError) invalid input syntax for integer: "-"
# LINE 1: ...601', 'R319', '00-03-00', 'DOOR OPEN', 2814000.0, '-', '2012...
#                                                              ^
#  [SQL: 'INSERT INTO raw (index, c_a, unit, scp, "desc", entries, exits, date_time) VALUES (%(index)s, %(c_a)s, %(unit)s, %(scp)s, %(desc)s, %(entries)s, %(exits)s, %(date_time)s)'] [parameters: ({'index': 0, 'c_a': 'A002', 'unit': 'R051', 'scp': '02-00-00', 'desc': 'REGULAR', 'entries': 3618144.0, 'exits': 1249112, 'date_time': datetime.datetime(2012, 4, 28, 0, 0)}, {'index': 1, 'c_a': 'A002', 'unit': 'R051', 'scp': '02-00-00', 'desc': 'REGULAR', 'entries': 3619169.0, 'exits': 1249424, 'date_time': datetime.datetime(2012, 4, 29, 4, 0)}, {'index': 2, 'c_a': 'A002', 'unit': 'R051', 'scp': '02-00-00', 'desc': 'REGULAR', 'entries': 3619991.0, 'exits': 1249972, 'date_time': datetime.datetime(2012, 4, 30, 12, 0)}, {'index': 3, 'c_a': 'A002', 'unit': 'R051', 'scp': '02-00-00', 'desc': 'REGULAR', 'entries': 3622745.0, 'exits': 1250665, 'date_time': datetime.datetime(2012, 5, 1, 20, 0)}, {'index': 4, 'c_a': 'A002', 'unit': 'R051', 'scp': '02-00-00', 'desc': 'REGULAR', 'entries': 3623480.0, 'exits': 1251176, 'date_time': datetime.datetime(2012, 5, 2, 16, 0)}, {'index': 5, 'c_a': 'A002', 'unit': 'R051', 'scp': '02-00-00', 'desc': 'REGULAR', 'entries': 3625978.0, 'exits': 1251819, 'date_time': datetime.datetime(2012, 5, 4, 0, 0)}, {'index': 6, 'c_a': 'A002', 'unit': 'R051', 'scp': '02-00-01', 'desc': 'REGULAR', 'entries': 3500018.0, 'exits': 751227, 'date_time': datetime.datetime(2012, 4, 28, 0, 0)}, {'index': 7, 'c_a': 'A002', 'unit': 'R051', 'scp': '02-00-01', 'desc': 'REGULAR', 'entries': 3500851.0, 'exits': 751408, 'date_time': datetime.datetime(2012, 4, 29, 4, 0)}  ... displaying 10 of 221861 total bound parameter sets ...  {'index': 221859, 'c_a': 'TRAM2', 'unit': 'R469', 'scp': '00-05-01', 'desc': 'REGULAR', 'entries': 5554.0, 'exits': 54.0, 'date_time': datetime.datetime(2012, 5, 3, 5, 0)}, {'index': 221860, 'c_a': 'TRAM2', 'unit': 'R469', 'scp': '00-05-01', 'desc': 'REGULAR', 'entries': 5554.0, 'exits': 54.0, 'date_time': datetime.datetime(2012, 5, 4, 13, 0)})]

# %%
split = old_files[old_files.index('raw_data/turnstile_120505.txt'):]
split[:5]
# Out:
# ['raw_data/turnstile_120505.txt',
#  'raw_data/turnstile_120512.txt',
#  'raw_data/turnstile_120519.txt',
#  'raw_data/turnstile_120526.txt',
#  'raw_data/turnstile_120602.txt']

# %%
test = load_turnstile_old(split[0])
# test.exits = test.exits.str.replace('-', '')
test.exits = pd.to_numeric(test.exits, errors='coerce')
test.head()
# Out:
# /opt/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2847: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     c_a  unit       scp     desc    entries      exits           date_time
# 0  A002  R051  02-00-00  REGULAR  3618144.0  1249112.0 2012-04-28 00:00:00
# 1  A002  R051  02-00-00  REGULAR  3619169.0  1249424.0 2012-04-29 04:00:00
# 2  A002  R051  02-00-00  REGULAR  3619991.0  1249972.0 2012-04-30 12:00:00
# 3  A002  R051  02-00-00  REGULAR  3622745.0  1250665.0 2012-05-01 20:00:00
# 4  A002  R051  02-00-00  REGULAR  3623480.0  1251176.0 2012-05-02 16:00:00

# %%
for filename in split:
    print(filename)
    df = load_turnstile_old(filename)
    df.exits = pd.to_numeric(df.exits, errors='coerce')
    df.to_sql('raw', engine, if_exists='append')
# Out:
# raw_data/turnstile_120505.txt
# /opt/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2847: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# raw_data/turnstile_120512.txt
# raw_data/turnstile_120519.txt
# raw_data/turnstile_120526.txt
# raw_data/turnstile_120602.txt
# raw_data/turnstile_120609.txt
# raw_data/turnstile_120616.txt
# raw_data/turnstile_120623.txt
# raw_data/turnstile_120630.txt
# raw_data/turnstile_120707.txt
# raw_data/turnstile_120714.txt
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/miniconda3/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     443             try:
# --> 444                 values, tz = tslib.datetime_to_datetime64(arg)
#     445                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64 (pandas/_libs/tslib.c:33275)()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-47db61b3a14c> in <module>()
#       1 for filename in split:
#       2     print(filename)
# ----> 3     df = load_turnstile_old(filename)
#       4     df.exits = pd.to_numeric(df.exits, errors='coerce')
#       5     df.to_sql('raw', engine, if_exists='append')
#
# <ipython-input-68-9a81ffe4b1cf> in load_turnstile_old(filename)
#       6     full_frame['date_time'] = pd.to_datetime(
#       7         full_frame.date + full_frame.time,
# ----> 8         format='%m-%d-%y%H:%M:%S')
#       9     full_frame.dropna(inplace=True)
#      10     full_frame.drop(['date', 'time'], axis=1, inplace=True)
#
# /opt/miniconda3/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     507     elif isinstance(arg, ABCSeries):
#     508         from pandas import Series
# --> 509         values = _convert_listlike(arg._values, False, format)
#     510         result = Series(values, index=arg.index, name=arg.name)
#     511     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# /opt/miniconda3/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     445                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     446             except (ValueError, TypeError):
# --> 447                 raise e
#     448
#     449     if arg is None:
#
# /opt/miniconda3/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     412                     try:
#     413                         result = tslib.array_strptime(arg, format, exact=exact,
# --> 414                                                       errors=errors)
#     415                     except tslib.OutOfBoundsDatetime:
#     416                         if errors == 'raise':
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_strptime (pandas/_libs/tslib.c:63619)()
#
# ValueError: time data '2NUMBER' does not match format '%m-%d-%y%H:%M:%S' (match)

# %%
test = pd.read_csv('raw_data/turnstile_120714.txt', skiprows=10, header=None)
test.head()
# Out:
#      0     1         2         3         4        5        6        7   \
# 0  A002  R051  02-00-00  07-11-12  16:00:00  REGULAR  3709772  1282349
# 1  A002  R051  02-00-00  07-13-12  00:00:00  REGULAR  3712452  1282996
# 2  A002  R051  02-00-01  07-07-12  00:00:00  REGULAR  3580147   769278
# 3  A002  R051  02-00-01  07-08-12  08:00:00  REGULAR  3581248   769419
# 4  A002  R051  02-00-01  07-09-12  00:00:00  REGULAR  3581747   769533
#
#          8         9     ...            33        34       35         36  \
# 0  07-11-12  20:00:00    ...      07-12-12  16:00:00  REGULAR  3711323.0
# 1  07-13-12  04:00:00    ...           NaN       NaN      NaN        NaN
# 2  07-07-12  04:00:00    ...      07-08-12  00:00:00  REGULAR  3581180.0
# 3  07-08-12  12:00:00    ...      07-08-12  16:00:00  REGULAR  3581492.0
# 4  07-09-12  04:00:00    ...      07-10-12  00:00:00  REGULAR  3583049.0
#
#           37        38        39       40         41         42
# 0  1282916.0  07-12-12  20:00:00  REGULAR  3712234.0  1282975.0
# 1        NaN       NaN       NaN      NaN        NaN        NaN
# 2   769400.0  07-08-12  04:00:00  REGULAR  3581222.0   769403.0
# 3   769495.0  07-08-12  20:00:00  REGULAR  3581683.0   769513.0
# 4   769797.0  07-10-12  04:00:00  REGULAR  3583069.0   769799.0
#
# [5 rows x 43 columns]

# %%
last_file = 'raw_data/turnstile_120714.txt'
split = old_files[old_files.index(last_file):]

filename = split.pop(0)
print(filename)
df = load_turnstile_old(filename, skiprows=10)
df.exits = pd.to_numeric(df.exits, errors='coerce')
df.to_sql('raw', engine, if_exists='append')

for filename in split:
    print(filename)
    df = load_turnstile_old(filename)
    df.exits = pd.to_numeric(df.exits, errors='coerce')
    df.to_sql('raw', engine, if_exists='append')
# Out:
# raw_data/turnstile_120714.txt
# raw_data/turnstile_120721.txt
# raw_data/turnstile_120728.txt
# raw_data/turnstile_120804.txt
# raw_data/turnstile_120811.txt
# raw_data/turnstile_120818.txt
# raw_data/turnstile_120825.txt
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/miniconda3/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     443             try:
# --> 444                 values, tz = tslib.datetime_to_datetime64(arg)
#     445                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64 (pandas/_libs/tslib.c:33275)()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-06db44abefc4> in <module>()
#      10 for filename in split:
#      11     print(filename)
# ---> 12     df = load_turnstile_old(filename)
#      13     df.exits = pd.to_numeric(df.exits, errors='coerce')
#      14     df.to_sql('raw', engine, if_exists='append')
#
# <ipython-input-83-58ab09b17cee> in load_turnstile_old(filename, **kwargs)
#       6     full_frame['date_time'] = pd.to_datetime(
#       7         full_frame.date + full_frame.time,
# ----> 8         format='%m-%d-%y%H:%M:%S')
#       9     full_frame.dropna(inplace=True)
#      10     full_frame.drop(['date', 'time'], axis=1, inplace=True)
#
# /opt/miniconda3/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     507     elif isinstance(arg, ABCSeries):
#     508         from pandas import Series
# --> 509         values = _convert_listlike(arg._values, False, format)
#     510         result = Series(values, index=arg.index, name=arg.name)
#     511     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# /opt/miniconda3/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     445                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     446             except (ValueError, TypeError):
# --> 447                 raise e
#     448
#     449     if arg is None:
#
# /opt/miniconda3/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     412                     try:
#     413                         result = tslib.array_strptime(arg, format, exact=exact,
# --> 414                                                       errors=errors)
#     415                     except tslib.OutOfBoundsDatetime:
#     416                         if errors == 'raise':
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_strptime (pandas/_libs/tslib.c:63619)()
#
# ValueError: time data 'FF-05-4008-22-12' does not match format '%m-%d-%y%H:%M:%S' (match)

# %%
pd.read_csv('raw_data/turnstile_120825.txt', engine='c').tail()
# Out:
#         A002  R051  02-00-00  08-18-12  00:00:00   REGULAR  003759779  \
# 28905  TRAM2  R469  00-05-01  08-20-12  17:00:00   REGULAR       5554
# 28906  TRAM2  R469  00-05-01  08-22-12  01:00:00   REGULAR       5554
# 28907  TRAM2  R469  00-05-01  08-23-12  09:00:00   REGULAR       5554
# 28908  TRAM2  R469  00-05-01  08-24-12  17:00:00   REGULAR       5554
# 28909    USE   NaN      R328  FF-05-40  08-22-12  16:02:48        101
#
#        001297676                                         08-18-12.1  04:00:00  \
# 28905         86                                           08-20-12  21:00:00
# 28906         86                                           08-22-12  05:00:00
# 28907         86                                           08-23-12  13:00:00
# 28908         86                                           08-24-12  21:00:00
# 28909  -16711708  -016763243                                    ...       NaN
#
#                                                                   ...                                                              \
# 28905                                                             ...
# 28906                                                             ...
# 28907                                                             ...
# 28908                                                             ...
# 28909                                                             ...
#
#        08-19-12  00:00:00.1  REGULAR.6 003760494 001297958 08-19-12.1  \
# 28905  08-21-12    17:00:00    REGULAR    5554.0      86.0   08-21-12
# 28906  08-23-12    01:00:00    REGULAR    5554.0      86.0   08-23-12
# 28907  08-24-12    09:00:00    REGULAR    5554.0      86.0   08-24-12
# 28908       NaN         NaN        NaN       NaN       NaN        NaN
# 28909       NaN         NaN        NaN       NaN       NaN        NaN
#
#        04:00:00.1  REGULAR.7 003760525  \
# 28905    21:00:00    REGULAR    5554.0
# 28906    05:00:00    REGULAR    5554.0
# 28907    13:00:00    REGULAR    5554.0
# 28908         NaN        NaN       NaN
# 28909         NaN        NaN       NaN
#
#       001297962
# 28905                                               86.0
# 28906                                               86.0
# 28907                                               86.0
# 28908                                                NaN
# 28909                                                NaN
#
# [5 rows x 43 columns]

# %%
last_file = 'raw_data/turnstile_120825.txt'
split = old_files[old_files.index(last_file):]

filename = split.pop(0)
print(filename)
df = load_turnstile_old(filename, skiprows=10)
df.exits = pd.to_numeric(df.exits, errors='coerce')
df.to_sql('raw', engine, if_exists='append')

for filename in split:
    print(filename)
    df = load_turnstile_old(filename)
    df.exits = pd.to_numeric(df.exits, errors='coerce')
    df.to_sql('raw', engine, if_exists='append')
# Out:
# raw_data/turnstile_120825.txt
# raw_data/turnstile_120901.txt
# raw_data/turnstile_120908.txt
# raw_data/turnstile_120915.txt
# raw_data/turnstile_120922.txt
# raw_data/turnstile_120929.txt
# raw_data/turnstile_121006.txt
# raw_data/turnstile_121013.txt
# raw_data/turnstile_121020.txt
# raw_data/turnstile_121027.txt
# raw_data/turnstile_121103.txt
# raw_data/turnstile_121110.txt
# raw_data/turnstile_121117.txt
# raw_data/turnstile_121124.txt
# raw_data/turnstile_121201.txt
# raw_data/turnstile_121208.txt
# raw_data/turnstile_121215.txt
# raw_data/turnstile_121222.txt
# raw_data/turnstile_121229.txt
# raw_data/turnstile_130105.txt
# raw_data/turnstile_130112.txt
# raw_data/turnstile_130119.txt
# raw_data/turnstile_130126.txt
# raw_data/turnstile_130202.txt
# raw_data/turnstile_130209.txt
# raw_data/turnstile_130216.txt
# raw_data/turnstile_130223.txt
# raw_data/turnstile_130302.txt
# raw_data/turnstile_130309.txt
# raw_data/turnstile_130316.txt
# raw_data/turnstile_130323.txt
# raw_data/turnstile_130330.txt
# raw_data/turnstile_130406.txt
# raw_data/turnstile_130413.txt
# raw_data/turnstile_130420.txt
# raw_data/turnstile_130427.txt
# raw_data/turnstile_130504.txt
# raw_data/turnstile_130511.txt
# raw_data/turnstile_130518.txt
# raw_data/turnstile_130525.txt
# raw_data/turnstile_130601.txt
# raw_data/turnstile_130608.txt
# raw_data/turnstile_130615.txt
# raw_data/turnstile_130622.txt
# raw_data/turnstile_130629.txt
# raw_data/turnstile_130706.txt
# raw_data/turnstile_130713.txt
# raw_data/turnstile_130720.txt
# raw_data/turnstile_130727.txt
# raw_data/turnstile_130803.txt
# raw_data/turnstile_130810.txt
# raw_data/turnstile_130817.txt
# raw_data/turnstile_130824.txt
# raw_data/turnstile_130831.txt
# raw_data/turnstile_130907.txt
# raw_data/turnstile_130914.txt
# raw_data/turnstile_130921.txt
# raw_data/turnstile_130928.txt
# raw_data/turnstile_131005.txt
# raw_data/turnstile_131012.txt
# raw_data/turnstile_131019.txt
# raw_data/turnstile_131026.txt
# raw_data/turnstile_131102.txt
# raw_data/turnstile_131109.txt
# raw_data/turnstile_131116.txt
# raw_data/turnstile_131123.txt
# raw_data/turnstile_131130.txt
# raw_data/turnstile_131207.txt
# raw_data/turnstile_131214.txt
# raw_data/turnstile_131221.txt
# raw_data/turnstile_131228.txt
# raw_data/turnstile_140104.txt
# raw_data/turnstile_140111.txt
# raw_data/turnstile_140118.txt
# raw_data/turnstile_140125.txt
# raw_data/turnstile_140201.txt
# raw_data/turnstile_140208.txt
# raw_data/turnstile_140215.txt
# raw_data/turnstile_140222.txt
# raw_data/turnstile_140301.txt
# raw_data/turnstile_140308.txt
# raw_data/turnstile_140315.txt
# raw_data/turnstile_140322.txt
# raw_data/turnstile_140329.txt
# raw_data/turnstile_140405.txt
# raw_data/turnstile_140412.txt
# raw_data/turnstile_140419.txt
# raw_data/turnstile_140426.txt
# raw_data/turnstile_140503.txt
# raw_data/turnstile_140510.txt
# raw_data/turnstile_140517.txt
# raw_data/turnstile_140524.txt
# raw_data/turnstile_140531.txt
# raw_data/turnstile_140607.txt
# raw_data/turnstile_140614.txt
# raw_data/turnstile_140621.txt
# raw_data/turnstile_140628.txt
# raw_data/turnstile_140705.txt
# raw_data/turnstile_140712.txt
# raw_data/turnstile_140719.txt
# raw_data/turnstile_140726.txt
# raw_data/turnstile_140802.txt
# raw_data/turnstile_140809.txt
# raw_data/turnstile_140816.txt
# raw_data/turnstile_140823.txt
# raw_data/turnstile_140830.txt
# raw_data/turnstile_140906.txt
# raw_data/turnstile_140913.txt
# raw_data/turnstile_140920.txt
# raw_data/turnstile_140927.txt
# raw_data/turnstile_141004.txt
# raw_data/turnstile_141011.txt

# %% [markdown]
# All files loaded into raw database. Now, we can pull and process to create clean tables in a new database. We'll have a table mapping station names to unit numbers and control areas, and a table for each station with times and riderships.
